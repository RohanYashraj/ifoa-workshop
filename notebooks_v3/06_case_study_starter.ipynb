# %% [markdown]
# # 06 · Case study starter
#
# **Workshop:** AI for Actuaries — From Foundations to AI Agents
# **Session / Part:** S2.P4  ·  **Slides:** S2.P4.9–10
# **Author:** Dr Rohan Yashraj Gupta (FIA, FIAI), with Satya Sai Mudigonda and Kasyap
# **Date:** 24 July 2026 · Four Points by Sheraton, Whitefield, Bangalore
# **Model:** `gemini-3.1-flash-lite` (pinned)  ·  **License:** CC BY-NC 4.0
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rohanyashraj/ifoa-workshop/blob/main/notebooks/06_case_study_starter.ipynb)
#
# ## What this notebook does
# Your 2-week case study. Three tracks, each ships a governed agent. Pick one, fill the TODOs, and bring a before/after guardrail trace. Due ~7 Aug 2026.
#
# *All data is hypothetical — ABC Insurer is a fictional entity for teaching only.
# The story: Priya Nair (pricing, ABC General) must explain the price of policy
# **ABC-MOT-047231** — a 7-year-old SUV, Tier-2, 35% NCB — so her chief actuary
# **Arjun Mehta** can sign it.*

# %% [markdown]
# ## The bar (all tracks)
# - A working agent that runs end-to-end from a clean environment.
# - Spec + system prompt as governed artefacts.
# - A **before/after trace** where a guardrail catches a failure.
# - The 10 checklist questions answered with evidence.
# - A one-page exec summary for a chief actuary.
#
# *The story: this is your own Priya-fortnight — your Arjun, your 200 policies.*

# %% [markdown]
# ## Track 1 — Model Build & Interpretation
# Wrap your models as tools; the agent runs the comparison.

# %%
# TODO Track 1:
# 1. Load YOUR dataset (or the ABC Health/Life books from notebook 02 patterns).
# 2. Fit a GLM + an XGBoost challenger; build an out-of-time lift table.
# 3. Wrap load/fit/lift/shap/summarise as tools (see notebook 05).
# 4. Add a guardrail that refuses leaky features. Capture a before/after trace.
pass

# %% [markdown]
# ## Track 2 — Documentation with GenAI (RAG + reviewer)

# %%
# TODO Track 2:
# 1. Collect 5-10 of your methodology snippets into a dict (see notebook 05, section 3).
# 2. Build search_methodology; require the agent to CITE a doc id for every claim.
# 3. Add a reviewer agent whose system prompt is the 10-question checklist.
# 4. Capture a trace where the reviewer sends an uncited draft back.
pass

# %% [markdown]
# ## Track 3 — Build a Simple AI Agent (Agno + Gemini, MCP)

# %%
# TODO Track 3:
# 1. Take the Pricing Logic Explainer (notebook 04) and port it to your line of business.
# 2. Add at least one deterministic guardrail; show it killing a hallucination.
# 3. (Ambitious) Wrap one tool as an MCP server callable from Claude Desktop.
# 4. Capture the before/after trace.
pass

# %% [markdown]
# ## Wrap-up
# Pick a track, form a team of ~5 (mixed LOB), and send Rohan your first trace.
#
# *Demonstrated: every track ships a governed agent — the biggest change from previous editions.*
